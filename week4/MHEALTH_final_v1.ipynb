# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonghoya/Machine-Learning-Programming/blob/main/week4/MHEALTH_final_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GroupKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from scipy import stats
from scipy.fft import fft
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import glob
import os
import warnings

warnings.filterwarnings('ignore')

# %%
# --- 1. Data Loading and Merging ---
print("--- 1. Data Loading and Merging ---")
# Specify the path to the dataset on Google Drive
path = '/content/drive/MyDrive/Colab Notebooks/MHEALTHDATASET'

if not os.path.isdir(path):
    print(f"⚠️ Error: Directory not found: {path}")
else:
    # Find all files matching the pattern
    all_files = sorted(glob.glob(os.path.join(path, "mHealth_subject*.log")))
    if not all_files:
        print(f"⚠️ Error: No 'mHealth_subject*.log' files found in '{path}'.")
    else:
        # Assuming 10 subject files are provided as per the requirement
        print(f"Found {len(all_files)} subject files. Assuming 10 for cross-validation setup.")
        li = []
        column_names = [
            'acc_chest_x', 'acc_chest_y', 'acc_chest_z',
            'ecg_lead1', 'ecg_lead2',
            'acc_ankle_x', 'acc_ankle_y', 'acc_ankle_z',
            'gyro_ankle_x', 'gyro_ankle_y', 'gyro_ankle_z',
            'mag_ankle_x', 'mag_ankle_y', 'mag_ankle_z',
            'acc_arm_x', 'acc_arm_y', 'acc_arm_z',
            'gyro_arm_x', 'gyro_arm_y', 'gyro_arm_z',
            'mag_arm_x', 'mag_arm_y', 'mag_arm_z',
            'label'
        ]
        feature_cols = column_names[:-1]

        for filename in all_files:
            df_temp = pd.read_csv(filename, header=None, sep=r'\s+')
            df_temp.columns = column_names
            subject_id = int(''.join(filter(str.isdigit, os.path.basename(filename))))
            df_temp['subject'] = subject_id
            li.append(df_temp)

        df = pd.concat(li, axis=0, ignore_index=True)
        # Remove Null class (label 0) as it is not an activity
        df = df[df['label'] != 0].reset_index(drop=True)

        print("✅ Data loaded and Null class removed successfully.")
        print(f"Overall data shape: {df.shape}")
        display(df.head())
# Out:
# --- 1. Data Loading and Merging ---
# Found 10 subject files. Assuming 10 for cross-validation setup.
# ✅ Data loaded and Null class removed successfully.
# Overall data shape: (343195, 25)
#    acc_chest_x  acc_chest_y  acc_chest_z  ecg_lead1  ecg_lead2  acc_ankle_x  \
# 0      -9.7788      0.55690      1.19750   0.008373  -0.033490       2.6493
# 1      -9.7733      0.27880      0.73036  -0.025118  -0.025118       2.4157
# 2      -9.8609      0.11561      0.79988   0.025118   0.016745       2.3865
# 3      -9.7409      0.17652      0.88957   0.180010   0.129770       2.3758
# 4      -9.7821      0.21637      0.90368   0.092098   0.046049       2.3239
#
#    acc_ankle_y  acc_ankle_z  gyro_ankle_x  gyro_ankle_y  ...  acc_arm_y  \
# 0      -9.4517      0.37683      -0.20965      -0.88931  ...    -9.0618
# 1      -9.5306      0.40179      -0.20965      -0.88931  ...    -9.2048
# 2      -9.5991      0.48141      -0.20037      -0.86867  ...    -9.1945
# 3      -9.5997      0.42919      -0.20037      -0.86867  ...    -9.1746
# 4      -9.5406      0.40038      -0.20037      -0.86867  ...    -9.2039
#
#    acc_arm_z  gyro_arm_x  gyro_arm_y  gyro_arm_z  mag_arm_x  mag_arm_y  \
# 0     1.8177   -0.058824    -0.93429    -0.34483   0.355370   -0.37003
# 1     1.5189   -0.058824    -0.93429    -0.34483   0.719910    0.17803
# 2     1.5507   -0.058824    -0.93429    -0.34483   0.355370   -0.37003
# 3     1.5413   -0.078431    -0.93429    -0.34052   0.357180   -0.18858
# 4     1.6127   -0.078431    -0.93429    -0.34052  -0.001887   -0.18867
#
#    mag_arm_z  label  subject
# 0   -0.35020      1        1
# 1    0.37363      1        1
# 2   -0.35020      1        1
# 3   -0.35198      1        1
# 4   -0.72017      1        1
#
# [5 rows x 25 columns]

# %%
# --- 2. Exploratory Data Analysis (EDA) ---
print("\n--- 2. Exploratory Data Analysis (EDA) ---")
# Add activity names for better visualization
activity_mapping = {
    1: 'Standing still', 2: 'Sitting and relaxing', 3: 'Lying down',
    4: 'Walking', 5: 'Climbing stairs', 6: 'Waist bends forward',
    7: 'Frontal elevation of arms', 8: 'Knees bending (crouching)',
    9: 'Cycling', 10: 'Jogging', 11: 'Running', 12: 'Jump front & back'
}
df['activity'] = df['label'].map(activity_mapping)
# Out:
# --- 2. Exploratory Data Analysis (EDA) ---

# %%
# Plot activity distribution
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(12, 8))
sns.countplot(y='activity', data=df, order=df['activity'].value_counts().index)
plt.title('Activity Distribution', fontsize=16)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Activity', fontsize=12)
plt.show()

# %%
# Plot data distribution per subject
plt.figure(figsize=(12, 6))
sns.countplot(x='subject', data=df)
plt.title('Data Distribution per Subject', fontsize=16)
plt.xlabel('Subject ID', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
# --- 3. Sliding Window Segmentation & Feature Engineering (Memory-Optimized) ---
print("\n--- 3. Starting Segmentation and Feature Engineering ---")

def get_fft_features(segment, n_fft=64):
    """Extract features from FFT"""
    fft_vals = fft(segment, n=n_fft)
    fft_abs = np.abs(fft_vals)
    return fft_abs[:n_fft // 2]

def create_segments_and_features_optimized(df, time_steps, step, feature_cols):
    # Calculate the exact number of segments that will be created
    num_segments = (len(df) - time_steps) // step + 1

    # Pre-allocate NumPy arrays to store the results
    raw_segments = np.empty((num_segments, time_steps, len(feature_cols)))

    num_engineered_features = 23 * 4 + 23 * 32
    engineered_features = np.empty((num_segments, num_engineered_features))

    labels = np.empty(num_segments, dtype=int)
    users = np.empty(num_segments, dtype=int)

    label_values = df['label'].values
    user_values = df['subject'].values

    idx = 0
    for i in range(0, len(df) - time_steps + 1, step):
        # 1. Raw time-series data segment
        raw_segment_df = df[feature_cols].iloc[i: i + time_steps]
        raw_segments[idx] = raw_segment_df.values

        # 2. Engineered features
        # Time-domain features
        mean = raw_segment_df.mean().values
        std = raw_segment_df.std().values
        maxx = raw_segment_df.max().values
        minn = raw_segment_df.min().values
        # Frequency-domain features
        fft_features = np.array([get_fft_features(raw_segment_df[col].values) for col in feature_cols]).flatten()

        engineered_features[idx] = np.concatenate([mean, std, maxx, minn, fft_features])

        # 3. Label and User info (stats.mode logic is maintained)
        label_result = stats.mode(label_values[i: i + time_steps], keepdims=True).mode[0]
        labels[idx] = np.array(label_result).flatten()[0]
        users[idx] = user_values[i]

        idx += 1

    return raw_segments, engineered_features, labels, users

# Parameters
Fs = 50
TIME_STEPS = int(Fs * 2.56)  # 128
STEP_SIZE = int(TIME_STEPS * 0.5) # 64
# Out:
# --- 3. Starting Segmentation and Feature Engineering ---

# %%
X_raw, X_feat, y, groups = create_segments_and_features_optimized(df, TIME_STEPS, STEP_SIZE, feature_cols)
# Adjust labels to start from 0
y = y - 1
NUM_CLASSES = len(np.unique(y))

# Create a LabelEncoder for mapping names in the final report
le = LabelEncoder()
le.fit(list(activity_mapping.values()))

print(f"✅ Segments created. Shapes: X_raw={X_raw.shape}, X_feat={X_feat.shape}, y={y.shape}, groups={groups.shape}")
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# ✅ Segments created. Shapes: X_raw=(5361, 128, 23), X_feat=(5361, 828), y=(5361,), groups=(5361,)
# Number of classes: 12

# %%
# --- 4. Hybrid CNN-LSTM + FNN Model Definition ---
class HAR_Hybrid_Model(nn.Module):
    def __init__(self, num_classes, num_raw_features, num_eng_features):
        super(HAR_Hybrid_Model, self).__init__()
        # Branch 1: CNN-LSTM for raw time-series data
        self.conv_layers = nn.Sequential(
            nn.Conv1d(in_channels=num_raw_features, out_channels=64, kernel_size=9, padding=4),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=2, stride=2)
        )
        self.lstm = nn.LSTM(input_size=64, hidden_size=128, num_layers=1, batch_first=True, dropout=0.5)

        # Branch 2: FNN for engineered features
        self.fnn_layers = nn.Sequential(
            nn.Linear(num_eng_features, 256),
            nn.ReLU(),
            nn.Dropout(0.5)
        )

        # Classifier: Combines outputs from both branches
        self.classifier = nn.Linear(128 + 256, num_classes)

    def forward(self, x_raw, x_feat):
        # Process raw data through CNN-LSTM branch
        x1 = x_raw.permute(0, 2, 1) # (N, L, C) -> (N, C, L) for Conv1d
        x1 = self.conv_layers(x1)
        x1 = x1.permute(0, 2, 1) # (N, C', L') -> (N, L', C') for LSTM
        x1, _ = self.lstm(x1)
        x1 = x1[:, -1, :] # Get last hidden state

        # Process engineered features through FNN branch
        x2 = self.fnn_layers(x_feat)

        # Concatenate outputs
        combined = torch.cat((x1, x2), dim=1)

        # Final classification
        out = self.classifier(combined)
        return out

# %%
# --- 5. Subject-wise Cross-Validation ---
print("\n--- 5. Starting Subject-wise Cross-Validation ---")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

N_SPLITS = 5
gkf = GroupKFold(n_splits=N_SPLITS)

fold_results = []
fold_accuracies = []
all_preds = []
all_labels = []
# Out:
# --- 5. Starting Subject-wise Cross-Validation ---
# Using device: cuda

# %%
for fold, (train_val_idx, test_idx) in enumerate(gkf.split(X_raw, y, groups)): # X_raw or X_feat can be used for splitting
    print(f"\n========== Fold {fold+1}/{N_SPLITS} ==========")

    model = HAR_Hybrid_Model(NUM_CLASSES, X_raw.shape[2], X_feat.shape[1]).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)

    # Split both feature datasets
    X_raw_train_val, X_raw_test = X_raw[train_val_idx], X_raw[test_idx]
    X_feat_train_val, X_feat_test = X_feat[train_val_idx], X_feat[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]

    # Data Scaling (fit on train, transform train and test)
    scaler_raw = StandardScaler()
    X_raw_train_val = scaler_raw.fit_transform(X_raw_train_val.reshape(-1, X_raw_train_val.shape[2])).reshape(X_raw_train_val.shape)
    X_raw_test = scaler_raw.transform(X_raw_test.reshape(-1, X_raw_test.shape[2])).reshape(X_raw_test.shape)

    scaler_feat = StandardScaler()
    X_feat_train_val = scaler_feat.fit_transform(X_feat_train_val)
    X_feat_test = scaler_feat.transform(X_feat_test)

    # Split train_val into train and validation sets
    X_raw_train, X_raw_val, X_feat_train, X_feat_val, y_train, y_val = train_test_split(
        X_raw_train_val, X_feat_train_val, y_train_val, test_size=0.1, random_state=42, stratify=y_train_val)

    # Create Tensors and DataLoaders (with two feature inputs)
    train_dataset = TensorDataset(torch.tensor(X_raw_train, dtype=torch.float32),
                                  torch.tensor(X_feat_train, dtype=torch.float32),
                                  torch.tensor(y_train, dtype=torch.long))
    val_dataset = TensorDataset(torch.tensor(X_raw_val, dtype=torch.float32),
                                torch.tensor(X_feat_val, dtype=torch.float32),
                                torch.tensor(y_val, dtype=torch.long))
    test_dataset = TensorDataset(torch.tensor(X_raw_test, dtype=torch.float32),
                                 torch.tensor(X_feat_test, dtype=torch.float32),
                                 torch.tensor(y_test, dtype=torch.long))

    train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

    # Model Training
    NUM_EPOCHS = 30
    history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}
    for epoch in range(NUM_EPOCHS):
        model.train()
        running_loss, correct_train, total_train = 0.0, 0, 0
        for segments_raw, segments_feat, labels in train_loader:
            segments_raw, segments_feat, labels = segments_raw.to(device), segments_feat.to(device), labels.to(device)

            outputs = model(segments_raw, segments_feat) # Pass both inputs to the model
            loss = criterion(outputs, labels)
            optimizer.zero_grad(); loss.backward(); optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct_train / total_train
        history['train_loss'].append(train_loss); history['train_acc'].append(train_acc)

        model.eval()
        running_loss, correct_val, total_val = 0.0, 0, 0
        with torch.no_grad():
            for segments_raw, segments_feat, labels in val_loader:
                segments_raw, segments_feat, labels = segments_raw.to(device), segments_feat.to(device), labels.to(device)
                outputs = model(segments_raw, segments_feat)
                loss = criterion(outputs, labels)
                running_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_loss = running_loss / len(val_loader)
        val_acc = 100 * correct_val / total_val
        history['val_loss'].append(val_loss); history['val_acc'].append(val_acc)

        print(f'Epoch [{epoch+1}/{NUM_EPOCHS}], Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')

    fold_results.append(history)

    # Model Evaluation
    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for segments_raw, segments_feat, labels in test_loader:
            segments_raw, segments_feat, labels = segments_raw.to(device), segments_feat.to(device), labels.to(device)
            outputs = model(segments_raw, segments_feat)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = 100 * correct / total
    fold_accuracies.append(accuracy)
    print(f'✅ Fold {fold+1} Test Accuracy: {accuracy:.2f} %')
# Out:
# ========== Fold 1/5 ==========
# Epoch [1/30], Train Loss: 0.8402, Train Acc: 78.02%, Val Loss: 0.1835, Val Acc: 96.98%
# Epoch [2/30], Train Loss: 0.1402, Train Acc: 97.44%, Val Loss: 0.0741, Val Acc: 98.84%
# Epoch [3/30], Train Loss: 0.0611, Train Acc: 98.68%, Val Loss: 0.0591, Val Acc: 99.07%
# Epoch [4/30], Train Loss: 0.0325, Train Acc: 99.35%, Val Loss: 0.0471, Val Acc: 99.07%
# Epoch [5/30], Train Loss: 0.0215, Train Acc: 99.66%, Val Loss: 0.0378, Val Acc: 99.07%
# Epoch [6/30], Train Loss: 0.0147, Train Acc: 99.77%, Val Loss: 0.0333, Val Acc: 99.07%
# Epoch [7/30], Train Loss: 0.0117, Train Acc: 99.79%, Val Loss: 0.0245, Val Acc: 99.30%
# Epoch [8/30], Train Loss: 0.0086, Train Acc: 99.92%, Val Loss: 0.0221, Val Acc: 99.54%
# Epoch [9/30], Train Loss: 0.0055, Train Acc: 99.95%, Val Loss: 0.0190, Val Acc: 99.77%
# Epoch [10/30], Train Loss: 0.0047, Train Acc: 99.97%, Val Loss: 0.0225, Val Acc: 99.54%
# Epoch [11/30], Train Loss: 0.0103, Train Acc: 99.90%, Val Loss: 0.0305, Val Acc: 99.30%
# Epoch [12/30], Train Loss: 0.0082, Train Acc: 99.85%, Val Loss: 0.0357, Val Acc: 99.30%
# Epoch [13/30], Train Loss: 0.0090, Train Acc: 99.85%, Val Loss: 0.0416, Val Acc: 98.61%
# Epoch [14/30], Train Loss: 0.0125, Train Acc: 99.74%, Val Loss: 0.0381, Val Acc: 98.84%
# Epoch [15/30], Train Loss: 0.0139, Train Acc: 99.69%, Val Loss: 0.0321, Val Acc: 99.07%
# Epoch [16/30], Train Loss: 0.0058, Train Acc: 99.92%, Val Loss: 0.0179, Val Acc: 99.54%
# Epoch [17/30], Train Loss: 0.0025, Train Acc: 100.00%, Val Loss: 0.0172, Val Acc: 99.54%
# Epoch [18/30], Train Loss: 0.0024, Train Acc: 99.97%, Val Loss: 0.0200, Val Acc: 99.54%
# Epoch [19/30], Train Loss: 0.0021, Train Acc: 100.00%, Val Loss: 0.0211, Val Acc: 99.30%
# Epoch [20/30], Train Loss: 0.0015, Train Acc: 100.00%, Val Loss: 0.0161, Val Acc: 99.54%
# Epoch [21/30], Train Loss: 0.0014, Train Acc: 99.97%, Val Loss: 0.0162, Val Acc: 99.54%
# Epoch [22/30], Train Loss: 0.0011, Train Acc: 100.00%, Val Loss: 0.0161, Val Acc: 99.54%
# Epoch [23/30], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0163, Val Acc: 99.77%
# Epoch [24/30], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0167, Val Acc: 99.77%
# Epoch [25/30], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.0167, Val Acc: 99.54%
# Epoch [26/30], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.0182, Val Acc: 99.54%
# Epoch [27/30], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.0189, Val Acc: 99.54%
# Epoch [28/30], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 0.0173, Val Acc: 99.54%
# Epoch [29/30], Train Loss: 0.0028, Train Acc: 99.90%, Val Loss: 0.0322, Val Acc: 99.07%
# Epoch [30/30], Train Loss: 0.0073, Train Acc: 99.74%, Val Loss: 0.0148, Val Acc: 99.77%
# ✅ Fold 1 Test Accuracy: 89.33 %
#
# ========== Fold 2/5 ==========
# Epoch [1/30], Train Loss: 0.9061, Train Acc: 74.88%, Val Loss: 0.2210, Val Acc: 95.57%
# Epoch [2/30], Train Loss: 0.1770, Train Acc: 96.37%, Val Loss: 0.0967, Val Acc: 97.67%
# Epoch [3/30], Train Loss: 0.0810, Train Acc: 98.44%, Val Loss: 0.0541, Val Acc: 98.37%
# Epoch [4/30], Train Loss: 0.0466, Train Acc: 99.01%, Val Loss: 0.0583, Val Acc: 98.14%
# Epoch [5/30], Train Loss: 0.0388, Train Acc: 99.33%, Val Loss: 0.0486, Val Acc: 98.83%
# Epoch [6/30], Train Loss: 0.0239, Train Acc: 99.64%, Val Loss: 0.0584, Val Acc: 98.14%
# Epoch [7/30], Train Loss: 0.0225, Train Acc: 99.56%, Val Loss: 0.0357, Val Acc: 98.83%
# Epoch [8/30], Train Loss: 0.0150, Train Acc: 99.71%, Val Loss: 0.0499, Val Acc: 98.83%
# Epoch [9/30], Train Loss: 0.0100, Train Acc: 99.90%, Val Loss: 0.0489, Val Acc: 98.60%
# Epoch [10/30], Train Loss: 0.0061, Train Acc: 100.00%, Val Loss: 0.0485, Val Acc: 98.83%
# Epoch [11/30], Train Loss: 0.0053, Train Acc: 99.97%, Val Loss: 0.0498, Val Acc: 99.07%
# Epoch [12/30], Train Loss: 0.0059, Train Acc: 99.92%, Val Loss: 0.0559, Val Acc: 99.07%
# Epoch [13/30], Train Loss: 0.0039, Train Acc: 100.00%, Val Loss: 0.0562, Val Acc: 98.60%
# Epoch [14/30], Train Loss: 0.0031, Train Acc: 99.97%, Val Loss: 0.0558, Val Acc: 98.83%
# Epoch [15/30], Train Loss: 0.0035, Train Acc: 99.95%, Val Loss: 0.0558, Val Acc: 98.83%
# Epoch [16/30], Train Loss: 0.0045, Train Acc: 99.95%, Val Loss: 0.0545, Val Acc: 98.83%
# Epoch [17/30], Train Loss: 0.0091, Train Acc: 99.84%, Val Loss: 0.0463, Val Acc: 98.83%
# Epoch [18/30], Train Loss: 0.0096, Train Acc: 99.79%, Val Loss: 0.0523, Val Acc: 98.60%
# Epoch [19/30], Train Loss: 0.0034, Train Acc: 99.97%, Val Loss: 0.0538, Val Acc: 98.60%
# Epoch [20/30], Train Loss: 0.0021, Train Acc: 100.00%, Val Loss: 0.0484, Val Acc: 98.83%
# Epoch [21/30], Train Loss: 0.0018, Train Acc: 100.00%, Val Loss: 0.0492, Val Acc: 98.83%
# Epoch [22/30], Train Loss: 0.0015, Train Acc: 99.97%, Val Loss: 0.0567, Val Acc: 98.83%
# Epoch [23/30], Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 0.0556, Val Acc: 98.83%
# Epoch [24/30], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0585, Val Acc: 98.83%
# Epoch [25/30], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0616, Val Acc: 98.83%
# Epoch [26/30], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0539, Val Acc: 99.07%
# Epoch [27/30], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.0627, Val Acc: 98.83%
# Epoch [28/30], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.0551, Val Acc: 99.07%
# Epoch [29/30], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 0.0564, Val Acc: 99.07%
# Epoch [30/30], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 0.0538, Val Acc: 99.07%
# ✅ Fold 2 Test Accuracy: 94.34 %
#
# ========== Fold 3/5 ==========
# Epoch [1/30], Train Loss: 0.8306, Train Acc: 77.35%, Val Loss: 0.2165, Val Acc: 95.57%
# Epoch [2/30], Train Loss: 0.1475, Train Acc: 96.99%, Val Loss: 0.1046, Val Acc: 96.50%
# Epoch [3/30], Train Loss: 0.0812, Train Acc: 97.67%, Val Loss: 0.0681, Val Acc: 97.90%
# Epoch [4/30], Train Loss: 0.0542, Train Acc: 98.76%, Val Loss: 0.0553, Val Acc: 98.60%
# Epoch [5/30], Train Loss: 0.0354, Train Acc: 99.20%, Val Loss: 0.0409, Val Acc: 98.60%
# Epoch [6/30], Train Loss: 0.0196, Train Acc: 99.59%, Val Loss: 0.0381, Val Acc: 98.83%
# Epoch [7/30], Train Loss: 0.0177, Train Acc: 99.59%, Val Loss: 0.0329, Val Acc: 98.83%
# Epoch [8/30], Train Loss: 0.0140, Train Acc: 99.82%, Val Loss: 0.0237, Val Acc: 98.83%
# Epoch [9/30], Train Loss: 0.0087, Train Acc: 99.95%, Val Loss: 0.0275, Val Acc: 98.83%
# Epoch [10/30], Train Loss: 0.0071, Train Acc: 99.95%, Val Loss: 0.0262, Val Acc: 98.60%
# Epoch [11/30], Train Loss: 0.0126, Train Acc: 99.77%, Val Loss: 0.0227, Val Acc: 99.07%
# Epoch [12/30], Train Loss: 0.0066, Train Acc: 99.92%, Val Loss: 0.0195, Val Acc: 99.30%
# Epoch [13/30], Train Loss: 0.0049, Train Acc: 99.97%, Val Loss: 0.0207, Val Acc: 99.30%
# Epoch [14/30], Train Loss: 0.0058, Train Acc: 99.90%, Val Loss: 0.0231, Val Acc: 99.30%
# Epoch [15/30], Train Loss: 0.0047, Train Acc: 99.95%, Val Loss: 0.0264, Val Acc: 98.83%
# Epoch [16/30], Train Loss: 0.0048, Train Acc: 99.92%, Val Loss: 0.0184, Val Acc: 99.30%
# Epoch [17/30], Train Loss: 0.0036, Train Acc: 99.97%, Val Loss: 0.0174, Val Acc: 99.30%
# Epoch [18/30], Train Loss: 0.0022, Train Acc: 99.97%, Val Loss: 0.0158, Val Acc: 99.53%
# Epoch [19/30], Train Loss: 0.0022, Train Acc: 99.97%, Val Loss: 0.0145, Val Acc: 99.30%
# Epoch [20/30], Train Loss: 0.0023, Train Acc: 99.97%, Val Loss: 0.0134, Val Acc: 99.30%
# Epoch [21/30], Train Loss: 0.0013, Train Acc: 100.00%, Val Loss: 0.0139, Val Acc: 99.30%
# Epoch [22/30], Train Loss: 0.0014, Train Acc: 99.97%, Val Loss: 0.0160, Val Acc: 99.07%
# Epoch [23/30], Train Loss: 0.0012, Train Acc: 99.97%, Val Loss: 0.0155, Val Acc: 99.07%
# Epoch [24/30], Train Loss: 0.0013, Train Acc: 99.97%, Val Loss: 0.0140, Val Acc: 99.30%
# Epoch [25/30], Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 0.0163, Val Acc: 99.30%
# Epoch [26/30], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0152, Val Acc: 99.30%
# Epoch [27/30], Train Loss: 0.0015, Train Acc: 99.97%, Val Loss: 0.0161, Val Acc: 99.30%
# Epoch [28/30], Train Loss: 0.0022, Train Acc: 99.97%, Val Loss: 0.0159, Val Acc: 99.30%
# Epoch [29/30], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0116, Val Acc: 99.53%
# Epoch [30/30], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 0.0119, Val Acc: 99.53%
# ✅ Fold 3 Test Accuracy: 91.52 %
#
# ========== Fold 4/5 ==========
# Epoch [1/30], Train Loss: 0.8617, Train Acc: 76.30%, Val Loss: 0.1748, Val Acc: 96.96%
# Epoch [2/30], Train Loss: 0.1580, Train Acc: 96.73%, Val Loss: 0.0813, Val Acc: 97.90%
# Epoch [3/30], Train Loss: 0.0729, Train Acc: 98.29%, Val Loss: 0.0553, Val Acc: 98.83%
# Epoch [4/30], Train Loss: 0.0473, Train Acc: 98.96%, Val Loss: 0.0468, Val Acc: 98.83%
# Epoch [5/30], Train Loss: 0.0399, Train Acc: 99.04%, Val Loss: 0.0522, Val Acc: 98.13%
# Epoch [6/30], Train Loss: 0.0265, Train Acc: 99.56%, Val Loss: 0.0380, Val Acc: 98.83%
# Epoch [7/30], Train Loss: 0.0196, Train Acc: 99.66%, Val Loss: 0.0335, Val Acc: 99.07%
# Epoch [8/30], Train Loss: 0.0195, Train Acc: 99.66%, Val Loss: 0.0531, Val Acc: 98.60%
# Epoch [9/30], Train Loss: 0.0182, Train Acc: 99.74%, Val Loss: 0.0433, Val Acc: 98.83%
# Epoch [10/30], Train Loss: 0.0109, Train Acc: 99.84%, Val Loss: 0.0369, Val Acc: 99.07%
# Epoch [11/30], Train Loss: 0.0074, Train Acc: 99.90%, Val Loss: 0.0393, Val Acc: 99.30%
# Epoch [12/30], Train Loss: 0.0056, Train Acc: 99.92%, Val Loss: 0.0347, Val Acc: 99.07%
# Epoch [13/30], Train Loss: 0.0049, Train Acc: 99.95%, Val Loss: 0.0393, Val Acc: 99.07%
# Epoch [14/30], Train Loss: 0.0030, Train Acc: 100.00%, Val Loss: 0.0392, Val Acc: 98.83%
# Epoch [15/30], Train Loss: 0.0031, Train Acc: 99.97%, Val Loss: 0.0420, Val Acc: 99.07%
# Epoch [16/30], Train Loss: 0.0038, Train Acc: 99.92%, Val Loss: 0.0395, Val Acc: 99.07%
# Epoch [17/30], Train Loss: 0.0026, Train Acc: 100.00%, Val Loss: 0.0399, Val Acc: 99.07%
# Epoch [18/30], Train Loss: 0.0017, Train Acc: 99.97%, Val Loss: 0.0421, Val Acc: 99.07%
# Epoch [19/30], Train Loss: 0.0020, Train Acc: 99.97%, Val Loss: 0.0460, Val Acc: 99.07%
# Epoch [20/30], Train Loss: 0.0012, Train Acc: 100.00%, Val Loss: 0.0480, Val Acc: 99.07%
# Epoch [21/30], Train Loss: 0.0012, Train Acc: 99.97%, Val Loss: 0.0505, Val Acc: 99.07%
# Epoch [22/30], Train Loss: 0.0012, Train Acc: 100.00%, Val Loss: 0.0504, Val Acc: 99.07%
# Epoch [23/30], Train Loss: 0.0018, Train Acc: 100.00%, Val Loss: 0.0496, Val Acc: 99.07%
# Epoch [24/30], Train Loss: 0.0031, Train Acc: 99.97%, Val Loss: 0.0413, Val Acc: 99.07%
# Epoch [25/30], Train Loss: 0.0022, Train Acc: 99.97%, Val Loss: 0.0332, Val Acc: 99.30%
# Epoch [26/30], Train Loss: 0.0038, Train Acc: 99.90%, Val Loss: 0.0508, Val Acc: 98.83%
# Epoch [27/30], Train Loss: 0.0155, Train Acc: 99.56%, Val Loss: 0.0349, Val Acc: 98.83%
# Epoch [28/30], Train Loss: 0.0046, Train Acc: 99.95%, Val Loss: 0.0356, Val Acc: 99.07%
# Epoch [29/30], Train Loss: 0.0027, Train Acc: 99.97%, Val Loss: 0.0452, Val Acc: 99.07%
# Epoch [30/30], Train Loss: 0.0013, Train Acc: 100.00%, Val Loss: 0.0421, Val Acc: 99.07%
# ✅ Fold 4 Test Accuracy: 93.99 %
#
# ========== Fold 5/5 ==========
# Epoch [1/30], Train Loss: 0.8711, Train Acc: 74.95%, Val Loss: 0.2718, Val Acc: 93.72%
# Epoch [2/30], Train Loss: 0.1695, Train Acc: 96.32%, Val Loss: 0.1544, Val Acc: 96.28%
# Epoch [3/30], Train Loss: 0.0855, Train Acc: 97.88%, Val Loss: 0.0904, Val Acc: 97.44%
# Epoch [4/30], Train Loss: 0.0542, Train Acc: 98.65%, Val Loss: 0.0818, Val Acc: 98.14%
# Epoch [5/30], Train Loss: 0.0325, Train Acc: 99.43%, Val Loss: 0.0630, Val Acc: 98.37%
# Epoch [6/30], Train Loss: 0.0230, Train Acc: 99.48%, Val Loss: 0.0709, Val Acc: 97.67%
# Epoch [7/30], Train Loss: 0.0173, Train Acc: 99.74%, Val Loss: 0.0592, Val Acc: 98.60%
# Epoch [8/30], Train Loss: 0.0134, Train Acc: 99.77%, Val Loss: 0.0612, Val Acc: 98.37%
# Epoch [9/30], Train Loss: 0.0417, Train Acc: 98.73%, Val Loss: 0.1145, Val Acc: 94.19%
# Epoch [10/30], Train Loss: 0.0246, Train Acc: 99.43%, Val Loss: 0.0484, Val Acc: 98.37%
# Epoch [11/30], Train Loss: 0.0092, Train Acc: 99.87%, Val Loss: 0.0463, Val Acc: 98.84%
# Epoch [12/30], Train Loss: 0.0065, Train Acc: 99.90%, Val Loss: 0.0449, Val Acc: 98.84%
# Epoch [13/30], Train Loss: 0.0047, Train Acc: 99.97%, Val Loss: 0.0494, Val Acc: 98.84%
# Epoch [14/30], Train Loss: 0.0034, Train Acc: 100.00%, Val Loss: 0.0461, Val Acc: 98.84%
# Epoch [15/30], Train Loss: 0.0028, Train Acc: 99.97%, Val Loss: 0.0453, Val Acc: 98.84%
# Epoch [16/30], Train Loss: 0.0024, Train Acc: 100.00%, Val Loss: 0.0411, Val Acc: 98.84%
# Epoch [17/30], Train Loss: 0.0020, Train Acc: 100.00%, Val Loss: 0.0436, Val Acc: 98.84%
# Epoch [18/30], Train Loss: 0.0017, Train Acc: 100.00%, Val Loss: 0.0465, Val Acc: 98.84%
# Epoch [19/30], Train Loss: 0.0012, Train Acc: 100.00%, Val Loss: 0.0499, Val Acc: 98.84%
# Epoch [20/30], Train Loss: 0.0012, Train Acc: 100.00%, Val Loss: 0.0512, Val Acc: 98.84%
# Epoch [21/30], Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 0.0500, Val Acc: 98.84%
# Epoch [22/30], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0508, Val Acc: 98.84%
# Epoch [23/30], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0531, Val Acc: 98.84%
# Epoch [24/30], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0547, Val Acc: 98.60%
# Epoch [25/30], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0489, Val Acc: 98.84%
# Epoch [26/30], Train Loss: 0.0016, Train Acc: 99.97%, Val Loss: 0.0440, Val Acc: 98.84%
# Epoch [27/30], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 0.0505, Val Acc: 98.84%
# Epoch [28/30], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 0.0574, Val Acc: 98.60%
# Epoch [29/30], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 0.0550, Val Acc: 98.84%
# Epoch [30/30], Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 0.0487, Val Acc: 98.60%
# ✅ Fold 5 Test Accuracy: 98.60 %

# %%
# --- 6. Training History Visualization ---
print("\n--- 6. Training History Visualization ---")
for i, history in enumerate(fold_results):
    plt.style.use('seaborn-v0_8-whitegrid')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    fig.suptitle(f'Fold {i+1} Training History', fontsize=18)

    ax1.plot(history['train_loss'], label='Train Loss', color='royalblue', marker='o', markersize=3)
    ax1.plot(history['val_loss'], label='Validation Loss', color='darkorange', marker='o', markersize=3)
    ax1.set_title('Training and Validation Loss'); ax1.set_xlabel('Epochs'); ax1.set_ylabel('Loss'); ax1.legend()

    ax2.plot(history['train_acc'], label='Train Accuracy', color='royalblue', marker='o', markersize=3)
    ax2.plot(history['val_acc'], label='Validation Accuracy', color='darkorange', marker='o', markersize=3)
    ax2.set_title('Training and Validation Accuracy'); ax2.set_xlabel('Epochs'); ax2.set_ylabel('Accuracy (%)'); ax2.legend()

    plt.tight_layout(); plt.show()
# Out:
# --- 6. Training History Visualization ---

# %%
# --- 7. Final Results ---
print("\n\n--- 7. Final Cross-Validation Results ---")
accuracies_np = np.array(fold_accuracies)
print(f"Accuracy per Fold: {accuracies_np}")
print(f"Average Accuracy: {accuracies_np.mean():.2f} %"); print(f"Standard Deviation of Accuracy: {accuracies_np.std():.2f}")
# Out:
# --- 7. Final Cross-Validation Results ---
# Accuracy per Fold: [89.32955619 94.34137291 91.51910531 93.98704903 98.59813084]
# Average Accuracy: 93.56 %
# Standard Deviation of Accuracy: 3.11

# %%
# --- 8. Classification Report & Confusion Matrix ---
print("\n--- 8. Classification Report & Confusion Matrix ---")
target_names_actual = [le.classes_[i] for i in sorted(np.unique(y))]

print(classification_report(all_labels, all_preds, target_names=target_names_actual))

cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=target_names_actual, yticklabels=target_names_actual)
plt.title('Confusion Matrix (All Folds)'); plt.xlabel('Predicted Label'); plt.ylabel('True Label'); plt.show()
# Out:
# --- 8. Classification Report & Confusion Matrix ---
#                            precision    recall  f1-score   support
#
#           Climbing stairs       0.99      0.99      0.99       483
#                   Cycling       0.98      0.89      0.93       480
# Frontal elevation of arms       0.99      1.00      1.00       480
#                   Jogging       0.99      0.99      0.99       480
#         Jump front & back       0.94      0.98      0.96       479
# Knees bending (crouching)       0.89      0.97      0.93       442
#                Lying down       0.99      1.00      0.99       460
#                   Running       0.86      0.84      0.85       458
#      Sitting and relaxing       1.00      0.97      0.99       480
#            Standing still       0.93      0.71      0.81       480
#       Waist bends forward       0.77      0.95      0.85       480
#                   Walking       0.97      0.94      0.96       159
#
#                  accuracy                           0.94      5361
#                 macro avg       0.94      0.94      0.94      5361
#              weighted avg       0.94      0.94      0.94      5361
